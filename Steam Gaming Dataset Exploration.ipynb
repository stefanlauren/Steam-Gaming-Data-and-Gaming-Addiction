# %% [markdown]
# # Steam Gaming Dataset Exploration
# By: Stefan Lauren
#
# Date: Mar 2019

# %% [markdown]
# Background: Steam is one of the largest gaming networks in the world with over 100 million active gamers. The Steam dataset covers 109 million user accounts, 196 million friendships, 3 million groups, 384 million owned games, and a collective 1 million years of playtime.
#
# The explanation of the data set could be found in https://steam.internet.byu.edu/

# %%
from pyspark import SparkConf, SparkContext, SQLContext
import pyspark.sql.functions as SqlF

# %%
try:
    sc = SparkContext()
    sqlContext = SQLContext(sc)
except ValueError:
    warnings.warn("SparkContext already exists in this scope")

# %% [markdown]
# ## 1. Data Collection

# %%
# File location
file_player_summaries = "steam_gaming_small\Player_Summaries.csv"
file_games_publishers = "steam_gaming_small\Games_Publishers.csv"
file_games_genres = "steam_gaming_small\Games_Genres.csv"
file_games_developers = "steam_gaming_small\Games_Developers.csv"
file_games_1 = "steam_gaming_small\Games_1.csv"

# %%
# Load all csv
df_games_publishers = sqlContext.read.format("csv").option("inferSchema", 
                                                           True).option("header", True).load(file_games_publishers)

df_games_genres = sqlContext.read.format("csv").option("inferSchema", 
                                                           True).option("header", True).load(file_games_genres)

df_games_developers = sqlContext.read.format("csv").option("inferSchema", 
                                                           True).option("header", True).load(file_games_developers)

df_games_1 = sqlContext.read.format("csv").option("inferSchema", 
                                                           True).option("header", True).load(file_games_1)

df_player_summaries = sqlContext.read.format("csv").option("inferSchema", 
                                                           True).option("header", True).load(file_player_summaries)

# %% [markdown]
# ## 2. Data Exploration

# %% [markdown]
# ### 2.1 Game Publishers

# %%
df_games_publishers.printSchema()
# Out:
# root
#  |-- appid: integer (nullable = true)
#  |-- Publisher: string (nullable = true)

# %%
df_games_publishers.show(5)
# Out:
# +------+---------+
# | appid|Publisher|
# +------+---------+
# |207990|     null|
# |215220|     null|
# |220824|     null|
# |241600|     null|
# |249310|     null|
# +------+---------+
# only showing top 5 rows

# %% [markdown]
# Game publishers table has appid as the id key for applications and publisher as the name of the publisher. There might be multiple rows with same appid, meaning that they publish an application together.

# %% [markdown]
# ### 2.2 Games Genres

# %%
df_games_genres.printSchema()
# Out:
# root
#  |-- appid: integer (nullable = true)
#  |-- Genre: string (nullable = true)

# %%
df_games_genres.show(5)
# Out:
# +-----+-----+
# |appid|Genre|
# +-----+-----+
# | 7290|  RPG|
# | 8980|  RPG|
# |18010|  RPG|
# |18040|  RPG|
# |24447|  RPG|
# +-----+-----+
# only showing top 5 rows

# %% [markdown]
# This is a table with the genre of application with id appid. An application may have more than one genre which are showed by multiple row with same appid.

# %% [markdown]
# ### 2.3 Games Developers

# %%
df_games_developers.printSchema()
# Out:
# root
#  |-- appid: integer (nullable = true)
#  |-- Developer: string (nullable = true)

# %%
df_games_developers.show(5)
# Out:
# +------+---------+
# | appid|Developer|
# +------+---------+
# |462530|       8i|
# |452420|       M2|
# |466530|       M2|
# |366960|       UD|
# |315060|      2SD|
# +------+---------+
# only showing top 5 rows

# %% [markdown]
# Developer is the name of the application's developer who made the application with id appid.

# %% [markdown]
# ### 2.4 Games 1

# %%
df_games_1.printSchema()
# Out:
# root
#  |-- steamid: long (nullable = true)
#  |-- appid: integer (nullable = true)
#  |-- playtime_2weeks: integer (nullable = true)
#  |-- playtime_forever: integer (nullable = true)
#  |-- dateretrieved: string (nullable = true)

# %%
df_games_1.show(5)
# Out:
# +-----------------+------+---------------+----------------+--------------------+
# |          steamid| appid|playtime_2weeks|playtime_forever|       dateretrieved|
# +-----------------+------+---------------+----------------+--------------------+
# |76561198001291264|  8870|           null|            1392|2013-06-09 01:01:...|
# |76561198001291264|   400|           null|             239|2013-06-09 01:01:...|
# |76561198001291264|212910|           null|             130|2013-06-09 01:01:...|
# |76561198001291264|   550|           null|           17547|2013-06-09 01:01:...|
# |76561198001291264|   420|           null|             534|2013-06-09 01:01:...|
# +-----------------+------+---------------+----------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# - steamid: user id
# - appid: collection of applications that the user has
# - playtime_2weeks: total amount of time during two weeks that the user spent on the application
# - playtime_forever: total amount of time the user spent on the application
# - dateretrieved: the first time the user got the application

# %% [markdown]
# ### 2.5 Player Summaries

# %%
df_player_summaries.printSchema()
# Out:
# root
#  |-- steamid: long (nullable = true)
#  |-- personaname: string (nullable = true)
#  |-- profileurl: string (nullable = true)
#  |-- avatar: string (nullable = true)
#  |-- avatarmedium: string (nullable = true)
#  |-- avatarfull: string (nullable = true)
#  |-- personastate: integer (nullable = true)
#  |-- communityvisibilitystate: integer (nullable = true)
#  |-- profilestate: integer (nullable = true)
#  |-- lastlogoff: timestamp (nullable = true)
#  |-- commentpermission: integer (nullable = true)
#  |-- realname: string (nullable = true)
#  |-- primaryclanid: long (nullable = true)
#  |-- timecreated: timestamp (nullable = true)
#  |-- gameid: integer (nullable = true)
#  |-- gameserverip: string (nullable = true)
#  |-- gameextrainfo: string (nullable = true)
#  |-- cityid: string (nullable = true)
#  |-- loccountrycode: string (nullable = true)
#  |-- locstatecode: string (nullable = true)
#  |-- loccityid: integer (nullable = true)
#  |-- dateretrieved: timestamp (nullable = true)

# %% [markdown]
# This table has 23 features so I will not show the first rows as they are not visually easy to interpret. Instead, I will give entry example for every feature.
#
# - steamid: user id (e.g. 76561198024350900)
# - personaname: in-game alias name (e.g. DGJarski)
# - profileurl: link to the profile (e.g. http://steamcommunity.com/profiles/76561198024350932/)
# - avatar: profile picture url (e.g. http://media.steampowered.com/steamcommunity/public/images/avatars/00/0005392e08218406955be6df367225d4b7a74783.jpg)
# - avatarmedium: medium size profile picture url (e.g. http://media.steampowered.com/steamcommunity/public/images/avatars/00/0005392e08218406955be6df367225d4b7a74783_medium.jpg)
# - avatarfull: full size profile picture url (e.g. http://media.steampowered.com/steamcommunity/public/images/avatars/00/0005392e08218406955be6df367225d4b7a74783_full.jpg)
# - personastate: - (e.g. 0)
# - communityvisibilitystate: - (e.g. 1)
# - profilestate: - (e.g. 1)
# - lastlogoff: the last time the user log off (e.g. 12/7/2011  2:31:52 AM)
# - commentpermission: - (e.g. 2)
# - realname: user real name (e.g. Brandon Taylor)
# - primaryclanid: group id (e.g. 103582791429650000)
# - timecreated: the time this account is created (e.g. 12/29/2004  9:00:06 AM)
# - gameid: id of the game the user was playing by the time the data were collected (e.g. 207890)
# - gameserverip: ip the user was used by the time the data were collected, by default it is 0.0.0.0:0 (e.g. 188.127.246.124:27705)
# - gameextrainfo: - (e.g. Football Manager 2013)
# - cityid: - (e.g. "")
# - loccountrycode: country code (e.g. US)
# - locstatecode: residence state (e.g. MI)
# - loccityid: city (e.g. 2082)
# - dateretrieved: timestamp (e.g. 3/8/2013  1:48:13 AM)

# %% [markdown]
# ### 2.6 Count the number of games per `publisher` and per `genre`
#
# To get the number of games per publisher, Games_Publishers table will be used. To get the number of games per genre, Games_Genre table will be used. The operations that I need are grouping the publisher and genre column; and count the number of application (appid) for every group.

# %%
# Number of games per publisher
df_games_publishers.createOrReplaceTempView("publishers")
games_per_publisher = sqlContext.sql("""
    SELECT Publisher, COUNT(appid) as Publisher_Count
    FROM publishers
    GROUP BY Publisher
    ORDER BY Publisher_Count desc
""")

games_per_publisher.show(games_per_publisher.count())
# Out:
# +--------------------+---------------+
# |           Publisher|Publisher_Count|
# +--------------------+---------------+
# |                null|           2627|
# |             Ubisoft|            384|
# |                SEGA|            349|
# |Dovetail Games - ...|            279|
# | Paradox Interactive|            246|
# |  Disney Interactive|            226|
# |          Activision|            221|
# |Feral Interactive...|            221|
# |              Degica|            190|
# |        Nordic Games|            164|
# |         Square Enix|            153|
# |            KISS ltd|            145|
# |Feral Interactive...|            143|
# |Wizards of the Co...|            135|
# |      Strategy First|            134|
# |            2K Games|            120|
# |              Capcom|            115|
# |Warner Bros. Inte...|            108|
# |Kalypso Media Dig...|            104|
# |         Deep Silver|             98|
# |       Sekai Project|             95|
# |  Night Dive Studios|             94|
# |      Dovetail Games|             93|
# |Dovetail Games - ...|             93|
# |    Devolver Digital|             88|
# |     Plug In Digital|             84|
# |     Slitherine Ltd.|             84|
# |          1C Company|             84|
# |BANDAI NAMCO Ente...|             81|
# |Focus Home Intera...|             79|
# |     Electronic Arts|             73|
# |Devolver Digital ...|             73|
# |   Black Shell Media|             71|
# |            Cakewalk|             70|
# |  PopCap Games, Inc.|             67|
# |         Codemasters|             65|
# |           N3V Games|             64|
# |          Viva Media|             62|
# |SQUARE ENIX, Eido...|             60|
# |     Choice of Games|             59|
# |         AGM PLAYISM|             56|
# |       Aerosoft GmbH|             56|
# |         Merge Games|             55|
# |           505 Games|             55|
# |United Independen...|             54|
# | Capcom U.S.A., Inc.|             54|
# |      Aldorlea Games|             53|
# |  Buka Entertainment|             52|
# |   Microsoft Studios|             52|
# |          MumboJumbo|             52|
# |KOEI TECMO GAMES ...|             51|
# |Idea Factory Inte...|             51|
# |Daedalic Entertai...|             51|
# |  Bethesda Softworks|             51|
# |  Team17 Digital Ltd|             49|
# |            Retroism|             49|
# |        Ronimo Games|             49|
# |  Gravity Europe SAS|             48|
# |      Ghostlight LTD|             48|
# |           Meridian4|             45|
# |               Valve|             43|
# |    Milestone S.r.l.|             43|
# |         1C-SoftClub|             42|
# | Iceberg Interactive|             42|
# |        SCS Software|             42|
# |Daybreak Game Com...|             42|
# |            Libredia|             41|
# | Aspyr (Mac & Linux)|             40|
# |        Headup Games|             40|
# |           Nyu Media|             40|
# |                  2K|             40|
# | Bohemia Interactive|             39|
# |Tripwire Interactive|             38|
# |           Rebellion|             38|
# |      Telltale Games|             37|
# |               Atari|             37|
# |        Trion Worlds|             36|
# |           LucasArts|             35|
# |Humongous Enterta...|             35|
# |Stardock Entertai...|             33|
# |           Lucasfilm|             31|
# |     Her Interactive|             30|
# |       Artifex Mundi|             30|
# | Topware Interactive|             28|
# |       Digital Tribe|             28|
# |       Winter Wolves|             28|
# |      Rockstar Games|             27|
# |3D Realms (Apogee...|             27|
# |Forever Entertain...|             26|
# |Trendy Entertainment|             26|
# |         id Software|             26|
# |         Nomad Games|             26|
# |         Aspyr (Mac)|             25|
# |        Mastertronic|             25|
# |   New Reality Games|             24|
# |    Fruitbat Factory|             24|
# |        GrabTheGames|             24|
# | Individual Software|             24|
# |Konami Digital En...|             23|
# |                iWin|             23|
# |    Funbox Media Ltd|             22|
# |  Aspyr (Mac, Linux)|             22|
# |            CI Games|             22|
# |     Netmarble Games|             21|
# |      Big Fish Games|             21|
# |           tinyBuild|             21|
# |    Arcen Games, LLC|             21|
# |Coffee Stain Studios|             21|
# |   Warner Home Video|             20|
# |      Positech Games|             20|
# | Robot Entertainment|             20|
# |  Three Flip Studios|             20|
# |        Ankama Games|             20|
# |    Adult Swim Games|             20|
# |      Dharker Studio|             20|
# |              SimBin|             20|
# |       Sandlot Games|             19|
# |The Fighter Colle...|             19|
# |            OGPlanet|             19|
# |Digerati Distribu...|             19|
# |Phoenix Online Pu...|             19|
# |Back To Basics Ga...|             19|
# |           PlayFirst|             19|
# |        Hosted Games|             18|
# |Gambitious Digita...|             18|
# |        SNK Playmore|             18|
# |   Spicy Horse Games|             18|
# |Gaijin Entertainment|             18|
# |       Best Way Soft|             18|
# |        Little Orbit|             18|
# |   Rising Star Games|             17|
# |               Nival|             17|
# |   AMPLITUDE Studios|             17|
# |        PlayWay S.A.|             17|
# |Kerberos Producti...|             17|
# |         InvertMouse|             17|
# |          MangaGamer|             16|
# |    Wadjet Eye Games|             16|
# |    Reverb Triple XP|             15|
# |           NovaLogic|             15|
# |              8Floor|             15|
# |En Masse Entertai...|             15|
# |       Curve Digital|             15|
# |Perfect World Ent...|             15|
# |              3000AD|             15|
# |       Sometimes You|             15|
# |   exosyphen studios|             15|
# |      OtakuMaker.com|             15|
# |Double Fine Produ...|             15|
# |astragon Entertai...|             15|
# |  Spiderweb Software|             15|
# |            ValuSoft|             15|
# |    Green Man Loaded|             14|
# |Alawar Entertainment|             14|
# |PlayStation Mobil...|             14|
# |     Zoo Corporation|             14|
# |             Realore|             14|
# |           VIZ Media|             14|
# |            Ripstone|             14|
# |        Gaijin Games|             14|
# | Jackbox Games, Inc.|             14|
# |  Neko Entertainment|             14|
# | Dagestan Technology|             14|
# |      Days of Wonder|             13|
# |             Egosoft|             13|
# |           Marvelous|             13|
# |D3Publisher of Am...|             13|
# |  Bigben Interactive|             13|
# |        b-alive gmbh|             13|
# | SOEDESCO Publishing|             13|
# |            BulkyPix|             13|
# | MAGIX Software GmbH|             13|
# |             ANPA.US|             12|
# |         Versus Evil|             12|
# |Slightly Mad Studios|             12|
# |     FireFly Studios|             12|
# | TopWare Interactive|             12|
# |           Excalibur|             12|
# |              Deck13|             12|
# |    Nkidu Games Inc.|             12|
# |  Klei Entertainment|             12|
# |  Uber Entertainment|             12|
# |              1C-777|             12|
# |              Funcom|             12|
# |           roseVeRte|             12|
# |        NeocoreGames|             12|
# |     Sigma Team Inc.|             12|
# |    Console Classics|             12|
# |    Last Day of Work|             12|
# |SmashMouth Games Ltd|             11|
# |  Trion Worlds, Inc.|             11|
# |         NIS America|             11|
# |      11 bit studios|             11|
# |ELYLAND  INVESTME...|             11|
# |       Tin Man Games|             11|
# |Digital Homicide ...|             11|
# |               XSEED|             11|
# |            Fatshark|             11|
# |          Frozenbyte|             11|
# |Wastelands Intera...|             11|
# |         SQUARE ENIX|             11|
# |    ASoundEffect.com|             11|
# |     Jetdogs Studios|             11|
# |     Surprise Attack|             11|
# | InterAction studios|             11|
# |      Interplay Inc.|             11|
# |   Reverb Publishing|             11|
# |                 THQ|             11|
# |     rondomedia GmbH|             11|
# |    CAPCOM Co., Ltd.|             11|
# |           Frogwares|             11|
# |        Kasedo Games|             11|
# |     1C Online Games|             11|
# |Wizards of the Coast|             11|
# |          Petroglyph|             10|
# |Introversion Soft...|             10|
# |     CINEMAX, s.r.o.|             10|
# |       NIKITA ONLINE|             10|
# |     Rockin' Android|             10|
# |                 CCP|             10|
# |       FIVE-BN GAMES|             10|
# |              Akella|             10|
# |inXile Entertainment|             10|
# |          Playbrains|             10|
# |Soldak Entertainment|             10|
# |       Lonely Troops|             10|
# |             Crytek |             10|
# |Trazzy Entertainment|             10|
# |Virtual Racing In...|              9|
# |   bitComposer Games|              9|
# |  Flying Interactive|              9|
# |         Aeria Games|              9|
# |          Koch Media|              9|
# |            Screen 7|              9|
# |      BlueLine Games|              9|
# |           Alientrap|              9|
# |Enlight Software ...|              9|
# |       Dogenzaka Lab|              9|
# | Gravity Interactive|              9|
# |            Mad Catz|              9|
# |GSC World Publishing|              9|
# |              DotEmu|              9|
# |            Techland|              9|
# |              Mode 7|              9|
# |  Nexon America Inc.|              9|
# |        Niffler Ltd.|              8|
# |        Autumn Games|              8|
# |   Black Lime Studio|              8|
# |              Sierra|              8|
# |    Fancy Fish Games|              8|
# |TopWare Interacti...|              8|
# |       Midnight City|              8|
# |    YGGDRASIL STUDIO|              8|
# |    Epic Quest Games|              8|
# |        Game Insight|              8|
# |ELYLAND  INVESTME...|              8|
# |     YoYo Games Ltd.|              8|
# |    INSGAMES LIMITED|              8|
# |Sapphire Dragon P...|              8|
# |             Cyanide|              8|
# |         Cyan Worlds|              8|
# |               ATLUS|              8|
# |Immanitas Enterta...|              8|
# |          DEZ Studio|              8|
# |            WB Games|              8|
# |Endless Loop Studios|              8|
# | GameArt Studio GmbH|              8|
# |  Noble Empire Corp.|              8|
# |       Ghost Machine|              8|
# |        Hanako Games|              8|
# |          Two Tribes|              8|
# |            FilmBuff|              8|
# |  Black Forest Games|              8|
# |       Tale of Tales|              8|
# |          Blaze Epic|              8|
# |    Siberian Digital|              8|
# | Dejobaan Games, LLC|              8|
# |             Eversim|              8|
# |          Futuremark|              8|
# |Alternative Softw...|              8|
# |      Larian Studios|              7|
# | Anarchy Enterprises|              7|
# |        Vostok Games|              7|
# | Quality Simulations|              7|
# | TREVA Entertainment|              7|
# |    Carpe Fulgur LLC|              7|
# |       Rainbow Games|              7|
# |           CyberLink|              7|
# |Hidden Path Enter...|              7|
# |     Triumph Studios|              7|
# |        Blendo Games|              7|
# |          Cleverweek|              7|
# |           JED GAMES|              7|
# |  Capcom U.S.A., Inc|              7|
# |         ORiGO GAMES|              7|
# |The Game Creators...|              7|
# |    Arc System Works|              7|
# |        Deadbreed AB|              7|
# |         Chucklefish|              7|
# |            Ludosity|              7|
# |                    |              7|
# |Cipher Prime Studios|              7|
# |Unknown Worlds En...|              7|
# |             Psyonix|              7|
# |H2 Interactive Co...|              7|
# |     Minor Key Games|              7|
# |               Kabam|              7|
# |         Ravenscourt|              6|
# |         Zachtronics|              6|
# |Konami Digital En...|              6|
# | Marvelous USA, Inc.|              6|
# |       Bossa Studios|              6|
# |      IV Productions|              6|
# |          Muse Games|              6|
# |      Amanita Design|              6|
# |    Frictional Games|              6|
# |   Might and Delight|              6|
# |     Giants Software|              6|
# |          inner seas|              6|
# |        Full Control|              6|
# |    Unwonted Studios|              6|
# |Tartezal Holdings...|              6|
# |   Wales Interactive|              6|
# |   Hyper Hippo Games|              6|
# |               Puuba|              6|
# |       Matthew Brown|              6|
# |Corrosive Studios...|              6|
# |       Hothead Games|              6|
# |         Gamersfirst|              6|
# |      CD PROJEKT RED|              6|
# |           RunServer|              6|
# |        The Behemoth|              6|
# |               Jagex|              6|
# |        Factus Games|              6|
# |           Clickteam|              6|
# |Majesco Entertain...|              6|
# |Kot in Action Cre...|              6|
# |         Puppy Games|              6|
# |           Zeiva Inc|              6|
# |   FromSoftware, Inc|              6|
# |          Games Farm|              6|
# |              Webzen|              6|
# |   Choice Provisions|              6|
# |Oddworld Inhabitants|              6|
# |      Prologue Games|              6|
# |     FlynnFour Games|              6|
# |Frontier Developm...|              6|
# |     Gigatross Games|              6|
# | Tactic Studios Inc.|              6|
# |     Spearhead Games|              6|
# |         Koch Media |              6|
# |  Shorebound Studios|              6|
# |    Play sp. z o. o.|              6|
# |    Sonic Boom Games|              6|
# |             Majesco|              6|
# |                 ACE|              6|
# |         Orangepixel|              5|
# | SmiteWorks USA, LLC|              5|
# |Desert Owl Games,...|              5|
# |         NSE Circuit|              5|
# |            Frogames|              5|
# |      Hi-Rez Studios|              5|
# |Axis Game Factory...|              5|
# |          Spicyhorse|              5|
# |           Ohm Force|              5|
# |      GSC Game World|              5|
# | Crescent Moon Games|              5|
# |Serious Games Int...|              5|
# |TaleWorlds Entert...|              5|
# |     Big Ant Studios|              5|
# | Gaslamp Games, Inc.|              5|
# |   IMCGAMES Co.,Ltd.|              5|
# |Revolution Softwa...|              5|
# |Cliffhanger Produ...|              5|
# |        HexWar Games|              5|
# |       Scott Cawthon|              5|
# |  Missing Link Games|              5|
# |         John Wizard|              5|
# |                 N/A|              5|
# |    Epic Games, Inc.|              5|
# |          WayForward|              5|
# |        Signo & Arte|              5|
# |            Nooskewl|              5|
# |Changyou.com Limited|              5|
# |     AAD Productions|              5|
# |           KOG Games|              5|
# |    FarSight Studios|              5|
# |Digital Leisure Inc.|              5|
# |      Eagle Dynamics|              5|
# |The Light Sword Team|              5|
# |     DreamsSoftGames|              5|
# |    Gearbox Software|              5|
# |        CivilSavages|              5|
# |       Chilled Mouse|              5|
# |Abyss Lights Stud...|              5|
# |              PopCap|              5|
# |   Niels Bauer Games|              5|
# |            Raw Fury|              5|
# |Namco Networks Am...|              5|
# |    EuroVideo Medien|              5|
# |            Owl Cave|              5|
# |                None|              5|
# |      WXP Games, LLC|              5|
# |        Artery Games|              5|
# | Twisted Pixel Games|              5|
# |     Absolutist Ltd.|              5|
# |   KranX Productions|              5|
# | Shaman Games Studio|              5|
# |   Panic Art Studios|              5|
# |            JAST USA|              5|
# |              NCsoft|              5|
# |  Piranha Games Inc.|              5|
# |           HeroCraft|              5|
# |            HuniePot|              5|
# |Tilted Mill Enter...|              5|
# |Ratalaika Games S.L.|              5|
# |       Double Eleven|              5|
# |Dusenberry Martin...|              5|
# |       Nexon America|              5|
# |    Surprise Attack |              5|
# |             Cheritz|              5|
# |BlueGiant Interac...|              5|
# |   Phr00t's Software|              5|
# |Microsoft Game St...|              5|
# |         Digital Eel|              5|
# |Suspicious Develo...|              5|
# |           RuneStorm|              5|
# |           eigoMANGA|              5|
# |     Size Five Games|              4|
# |        Turtle Cream|              4|
# |          Futuretown|              4|
# |       Nicalis, Inc.|              4|
# |      Snowbird Games|              4|
# |        Schell Games|              4|
# |            NVLMaker|              4|
# |Big Fat Simulatio...|              4|
# |Image Space Incor...|              4|
# |        Inky Mind UK|              4|
# |Konami Digital En...|              4|
# |          10tons Ltd|              4|
# |Love Conquers All...|              4|
# |   Nexon Europe GmbH|              4|
# |     Alexander Byzov|              4|
# |              PikPok|              4|
# |      Mi-Clos Studio|              4|
# |            M. Yuriy|              4|
# |       Screaming Bee|              4|
# |         ShareX Team|              4|
# |  Blue Mammoth Games|              4|
# |          Atriagames|              4|
# |        Tortuga Team|              4|
# |  Mommy's Best Games|              4|
# |      Capybara Games|              4|
# |             DQ Team|              4|
# |   NIS America, Inc.|              4|
# |        Stoic Studio|              4|
# |Gaijin Entertainm...|              4|
# |      Reloaded Games|              4|
# |Cliffhanger Produ...|              4|
# |          Youdagames|              4|
# |     Cold Beam Games|              4|
# |    Ranmantaru Games|              4|
# |             Beamdog|              4|
# |       Berserk Games|              4|
# |GameMill Entertai...|              4|
# |       Nemesys Games|              4|
# |    DrinkBox Studios|              4|
# |         Toxic Games|              4|
# |Oddworld Inhabita...|              4|
# |          Brainchild|              4|
# |    Makivision Games|              4|
# |       Tagstar Games|              4|
# |       Vertigo Games|              4|
# |    Cherry Pop Games|              4|
# | Infernum Games GmbH|              4|
# |Peoleo Entertainment|              4|
# |  TreeFortress Games|              4|
# |       Rake in Grass|              4|
# |Evilized productions|              4|
# |        Warner Bros.|              4|
# |    Vae Victis Games|              4|
# |Hassey Enterprise...|              4|
# |  Soccer Manager Ltd|              4|
# |  Tribute Games Inc.|              4|
# |  Retro Army Limited|              4|
# |       Wargaming.net|              4|
# |               Flazm|              4|
# |            Re-Logic|              4|
# |  Thegamewallstudios|              4|
# |          38 Studios|              4|
# |           Dead Mage|              4|
# |    Microblast Games|              4|
# |      Basilisk Games|              4|
# |     Doublesix Games|              4|
# |       Allegorithmic|              4|
# |        Chubby Pixel|              4|
# |  Blind Mind Studios|              4|
# |             Moonpod|              4|
# |Sony Creative Sof...|              4|
# |     David Szymanski|              4|
# |Blazing Griffin Ltd.|              4|
# |        AJTilley.com|              4|
# |   Gameforge 4D GmbH|              4|
# |            EQ Games|              4|
# | Black Cloud Studios|              4|
# |               ISOTX|              4|
# |        Cobra Mobile|              4|
# |       Krome Studios|              4|
# |Light Vision Inte...|              4|
# |         WildTangent|              4|
# |Bit Planet Games,...|              4|
# |           2tainment|              4|
# |               IPACS|              4|
# |The Sleeping Machine|              4|
# |RaceRoom Entertai...|              4|
# |      Smilegate West|              4|
# |Illwinter Game De...|              4|
# |Next Dimension Ga...|              4|
# |   Andrii Vintsevych|              4|
# |     DnS Development|              4|
# |         Argus Games|              4|
# |    FiolaSoft Studio|              4|
# |       Owlchemy Labs|              4|
# |             WG Labs|              4|
# |Game Factory Inte...|              4|
# |               Finji|              4|
# | Keen Software House|              4|
# |   Biart Company LLC|              4|
# |    Born Ready Games|              4|
# |            Brawsome|              4|
# |   Three Donkeys LLC|              4|
# |INTI CREATES CO.,...|              4|
# |Gazillion Enterta...|              4|
# |   Digital Happiness|              4|
# | Stainless Games Ltd|              4|
# |    Blowfish Studios|              4|
# |      Shadow Masters|              4|
# |Interplay Enterta...|              4|
# |        EXOR Studios|              4|
# |  Big Sandwich Games|              4|
# |                GTGD|              4|
# |         Sasha Darko|              4|
# |Ubisoft Entertain...|              4|
# |   Ankama Animations|              4|
# |        Carbon Games|              4|
# |       Alice & Smith|              4|
# |    Stunlock Studios|              4|
# |  Glass Bottom Games|              4|
# |        Legacy Games|              4|
# |        LookAtMyGame|              4|
# |        Dorado Games|              4|
# |      Northway Games|              4|
# |      Red Redemption|              4|
# |       Pixel Ferrets|              4|
# |        Anvate Games|              4|
# |        OhNoo Studio|              4|
# |          Fish Eagle|              4|
# |          Dreamatrix|              4|
# |         NGD Studios|              4|
# |   The Game Creators|              4|
# |      Phosphor Games|              4|
# |        Thesis Games|              4|
# |   Milkstone Studios|              4|
# |             Threaks|              3|
# |           2x2 Games|              3|
# |          Machine 22|              3|
# |         Runic Games|              3|
# |    phime studio LLC|              3|
# |      Signal Studios|              3|
# |         mamor games|              3|
# |      Terry Cavanagh|              3|
# |articy Software G...|              3|
# |            REMIMORY|              3|
# |     Artifice Studio|              3|
# |        XGen Studios|              3|
# |   MinMax Games Ltd.|              3|
# |Zero Rock Enterta...|              3|
# |         Psyop Games|              3|
# | TheGameWall Studios|              3|
# |         Rotten Mage|              3|
# |         Sunside Inc|              3|
# |   RailSimulator.com|              3|
# |Afterthought Studios|              3|
# |   Fun Infused Games|              3|
# |    rokapublish GmbH|              3|
# | A Crowd of Monsters|              3|
# |              Dvaput|              3|
# |         Zoink Games|              3|
# |Heartbit Interactive|              3|
# |      Lightbulb Crew|              3|
# |       Squiddershins|              3|
# |      Saibot Studios|              3|
# |          Dahlenburg|              3|
# |Application Syste...|              3|
# |           Holy Warp|              3|
# |    Avatar Creations|              3|
# |         MAG Studios|              3|
# |          Mousechief|              3|
# |Q Entertainment Inc.|              3|
# |            Grey Box|              3|
# |    TimeGate Studios|              3|
# |   Flox Studios Ltd.|              3|
# |       Pom Pom Games|              3|
# |    SimProse Studios|              3|
# |             MoaCube|              3|
# |     Funktronic Labs|              3|
# |      Nekomura Games|              3|
# |            Wingware|              3|
# |         Four Lights|              3|
# |Running With Scis...|              3|
# |Aterdux Entertain...|              3|
# |       Reiza Studios|              3|
# |       Kingdom Games|              3|
# |       Maximum Games|              3|
# |       Teotl Studios|              3|
# |          Suba Games|              3|
# |            Hitcents|              3|
# |       Tru Blu Games|              3|
# |                 M2H|              3|
# |            PlazSoft|              3|
# |   ScrewAttack Games|              3|
# |       Seaven Studio|              3|
# |    Iceflake Studios|              3|
# |    Karaokulta Games|              3|
# |            IMGN.PRO|              3|
# |     Eden Industries|              3|
# |          WTFOMGames|              3|
# | Lunar Giant Studios|              3|
# |Ritual Entertainment|              3|
# |Roencia Game Crea...|              3|
# |  Michael Todd Games|              3|
# |Rock Hippo Produc...|              3|
# |         Adhoc Games|              3|
# |    Snake Hill Games|              3|
# |  Sports Mogul, Inc.|              3|
# |     Numantian Games|              3|
# |         Locomotivah|              3|
# |      Geoff Keighley|              3|
# |Dark Day Interactive|              3|
# |     Bloober Team SA|              3|
# |Aspyr (Mac and Li...|              3|
# |            2DEngine|              3|
# |Remedy Entertainment|              3|
# |          WaterMelon|              3|
# |          REEW GAMES|              3|
# |  BattleGoat Studios|              3|
# |Piko Interactive LLC|              3|
# |       Rsupport Inc.|              3|
# |    Kisareth Studios|              3|
# |    Krillbite Studio|              3|
# |       Badland Indie|              3|
# |        Ambiera e.U.|              3|
# |           Lionsgate|              3|
# |        Octopus Tree|              3|
# |        Frima Studio|              3|
# |           Graviteam|              3|
# |           YFC games|              3|
# |              Hexage|              3|
# | Cadenza Interactive|              3|
# |          QCF Design|              3|
# |      Brandon Brizzi|              3|
# |        Room710Games|              3|
# |Piranha Bytes Dis...|              3|
# |Mechanical Butter...|              3|
# |         Red Barrels|              3|
# |GungHo Online Ent...|              3|
# |            Pirozhok|              3|
# |              Mojang|              3|
# |            Question|              3|
# |       Misfits Attic|              3|
# |Supreme Clans Ent...|              3|
# |  Cowardly Creations|              3|
# |Sakura River Inte...|              3|
# |            EJRGames|              3|
# |          ACE MADDOX|              3|
# |    Degica Co., Ltd.|              3|
# |    Screwfly Studios|              3|
# | Glass Knuckle Games|              3|
# |            Konsordo|              3|
# |      Dylan Fitterer|              3|
# |             VaragtP|              3|
# |         Omega Games|              3|
# |           JoyMasher|              3|
# |         Armor Games|              3|
# |              NCSOFT|              3|
# |          Axis Games|              3|
# |Rising Sun Intera...|              3|
# |             Krealit|              3|
# |      ONE MORE LEVEL|              3|
# |           inkle Ltd|              3|
# |               Aspyr|              3|
# |        Sirlin Games|              3|
# |      Citeremis Inc.|              3|
# |      Serenity Forge|              3|
# |   Nexon GT Co., Ltd|              3|
# |             Nicalis|              3|
# |      Terminal Press|              3|
# |Hajime Doujin Circle|              3|
# |     Indomitus Games|              3|
# |       WarGirl Games|              3|
# |     Red Splat Games|              3|
# |Lupus Studios Lim...|              3|
# |Smudged Cat Games...|              3|
# |              eduweb|              3|
# |      Noumenon Games|              3|
# |       Chronic Logic|              3|
# |       Gamepot, Inc.|              3|
# |Doctor Entertainm...|              3|
# |          Lace Games|              3|
# |        Tonguç Bodur|              3|
# |  Leadwerks Software|              3|
# |        Broken Rules|              3|
# |    Polynetix Studio|              3|
# |      Critical Games|              3|
# |Vysoko Anime Prod...|              3|
# |DoubleBear Produc...|              3|
# |     Skobbejak Games|              3|
# |        Jason Rohrer|              3|
# |Panzer Gaming Stu...|              3|
# |            ND Games|              3|
# |           Kenny Sun|              3|
# |          Puny Human|              3|
# |          1337 Games|              3|
# |              CPsoft|              3|
# |     Edmund McMillen|              3|
# |        Nimbly Games|              3|
# |         Studio Evil|              3|
# |    Himalaya Studios|              3|
# |  Squid In A Box Ltd|              3|
# |Shangri-La Game S...|              3|
# |        Ripstone Ltd|              3|
# |Stegalosaurus Gam...|              3|
# |            Nuligine|              3|
# |     Binary Takeover|              3|
# |     Ivanovich Games|              3|
# |           Caiysware|              3|
# |   Curvature Systems|              3|
# |        Gamestorming|              3|
# |    Psychic Software|              3|
# | 9heads Game Studios|              3|
# |      HyperKat Games|              3|
# |Nexon Europe S.a.r.l|              3|
# |       GamesBoosters|              3|
# |      Freebird Games|              3|
# |     For All To Play|              3|
# |  Black Pants Studio|              3|
# |otherland co-prod...|              3|
# | Kittehface Software|              3|
# |         Secret Base|              3|
# |       Legend Studio|              3|
# |  Forever Humble PDX|              3|
# |Double Fine Presents|              3|
# |      Trese Brothers|              3|
# |     Apogee Software|              3|
# |             DarkGod|              3|
# |      Rockin Android|              3|
# |        Kazakov Oleg|              3|
# |       Cult Software|              3|
# |       Yai Gameworks|              3|
# |   Tri Synergy, Inc.|              3|
# |         Crytek GmbH|              3|
# |      C63 Industries|              3|
# |         electrolyte|              3|
# |   DTP Entertainment|              3|
# |               Nexon|              3|
# |           Russpuppy|              3|
# |Shortbreak Studio...|              3|
# |         The Foundry|              3|
# |           Andrettin|              3|
# |           SFB Games|              3|
# |Harebrained Holdings|              3|
# |    Screwy Lightbulb|              3|
# |      Red Fly Studio|              3|
# | Killmonday Games HB|              3|
# |     Chasing Carrots|              3|
# |              khos85|              3|
# |       Quantized Bit|              3|
# |            Vlambeer|              3|
# |          GenomGames|              3|
# |     Ocean Media LLC|              3|
# |            Pixeljam|              3|
# |  From Soy Sauce LLC|              3|
# | Strategy First Inc.|              3|
# |            Positech|              3|
# |    DarkArts Studios|              3|
# |       Games Starter|              3|
# |           StaudSoft|              2|
# |            NinjaBee|              2|
# |       iFun4all Ltd.|              2|
# |Precision Games, LLC|              2|
# |        Winter Bloom|              2|
# |The Secret Games ...|              2|
# |Spike Chunsoft Co...|              2|
# |         Patagoniart|              2|
# | OMNIDREAM CREATIONS|              2|
# |        Cosmic Logic|              2|
# |   Facepunch Studios|              2|
# |         Tuomo Laine|              2|
# |            Gneu LLC|              2|
# |         Bigger Boat|              2|
# |      BBEW BBEW, LLC|              2|
# |From Nothing Game...|              2|
# |BANDAI NAMCO Ente...|              2|
# |          Mystic Box|              2|
# |Renegade Sector G...|              2|
# |     JMJ Interactive|              2|
# |             Fresh3D|              2|
# |   Osprey Publishing|              2|
# |Argonauts Interac...|              2|
# |            NotGames|              2|
# |     Digitalmindsoft|              2|
# |         Matt Roszak|              2|
# |Silver Sphere Stu...|              2|
# | Minority Media Inc.|              2|
# |         AGM Playism|              2|
# |  FromSoftware, Inc.|              2|
# |         Phantom EFX|              2|
# |             Murudai|              2|
# |Infinite Dreams s...|              2|
# |     Instant Kingdom|              2|
# |      bitSmith Games|              2|
# |    Thinking Studios|              2|
# |            Autodesk|              2|
# |           U.S. Army|              2|
# |    Dedication Games|              2|
# |       Jet Set Games|              2|
# |Paradox Interactive |              2|
# |     Lucid Games Ltd|              2|
# |           Jan Zizka|              2|
# |Doomster Entertai...|              2|
# |   Guard Crush Games|              2|
# |        Space Wedgie|              2|
# |       KURONEKO SOFT|              2|
# |         Tri Synergy|              2|
# |Candella Systems Ltd|              2|
# |       Juri Schupilo|              2|
# |          Hempuli Oy|              2|
# |       Games Faction|              2|
# |           BetaDwarf|              2|
# |Daedalic Entertai...|              2|
# |  A Stranger Gravity|              2|
# |Gag A Maggot Ente...|              2|
# |        Young Horses|              2|
# |         Shark Punch|              2|
# |           AvrDragon|              2|
# |        Serellan LLC|              2|
# |      Viva Media Inc|              2|
# |            Playdead|              2|
# |Paradox Developme...|              2|
# |     Narrow Monolith|              2|
# |  Peaksel D.O.O. Nis|              2|
# |     Codebrush Games|              2|
# |              TERNOX|              2|
# |  Nine Tales Digital|              2|
# |            Frogmind|              2|
# |           Pheenix93|              2|
# |  Travian Games GmbH|              2|
# |           Breakfall|              2|
# |     Edge of Reality|              2|
# |         Age of Fear|              2|
# |             2K Play|              2|
# |    Grey Alien Games|              2|
# |           Game-Labs|              2|
# |      Epiphany Games|              2|
# |  CloudTheWolf Games|              2|
# |          Cinemaware|              2|
# |       Pixel Maniacs|              2|
# |           Triverske|              2|
# |      Sascha Hartleb|              2|
# |          Stroboskop|              2|
# |XTeam Software So...|              2|
# | Freakinware Studios|              2|
# |             Damaged|              2|
# |      Tochas Studios|              2|
# |  TheShortAndTheTall|              2|
# |       Crytivo Games|              2|
# |             SaintXi|              2|
# |         Lever Games|              2|
# |  Dust Scratch Games|              2|
# |          Animu Game|              2|
# |         nornware AB|              2|
# |        Mystic Games|              2|
# |      Funcraft Games|              2|
# |            Valusoft|              2|
# |   Lost Decade Games|              2|
# |     Payload Studios|              2|
# |        Brain Blinks|              2|
# |     Shumkov Dmitriy|              2|
# |         Artem Kotov|              2|
# |     Last Life Games|              2|
# |      Last Dimension|              2|
# |           RageSquid|              2|
# |      Pixel Pi Games|              2|
# |    Daylight Studios|              2|
# |Fixpoint Producti...|              2|
# |         React Games|              2|
# |      Buffalo Vision|              2|
# |             WaveDNA|              2|
# |       Arthur Kariev|              2|
# |    Red Hook Studios|              2|
# |          Frozen Dev|              2|
# |   Lucid Sight, Inc.|              2|
# |          Pepi Games|              2|
# |Ginormocorp Holdi...|              2|
# |         Aksys Games|              2|
# |        Erik Svedäng|              2|
# |                Ganz|              2|
# |    Diggidy.net, LLC|              2|
# |iEntertainment Ne...|              2|
# |        Boncho Games|              2|
# |  Black Market Games|              2|
# |        E-Line Media|              2|
# |     Polykroma Games|              2|
# |       Erotes studio|              2|
# |       Logic Artists|              2|
# |             Sytexis|              2|
# |         Dingo Games|              2|
# |         Hello Games|              2|
# |    Nauris Amatnieks|              2|
# |      Michael Brough|              2|
# |        Inmatrix LTD|              2|
# |        @unepic_fran|              2|
# |          Crian Soft|              2|
# |            Kurechii|              2|
# |Incandescent Imaging|              2|
# |    Interbellum team|              2|
# |Opium Pulses Ente...|              2|
# |       RadiationBurn|              2|
# |        Songquito UG|              2|
# |      Infotread, LLC|              2|
# |              G2CREW|              2|
# |    Digital Extremes|              2|
# |    Expansive Worlds|              2|
# |      Joe Richardson|              2|
# |Interabang Entert...|              2|
# |        Jardel Elias|              2|
# |          FreezeNova|              2|
# |        Space Budgie|              2|
# |            Red Beat|              2|
# |        Bacq Stellan|              2|
# |Destructive Creat...|              2|
# |      North of Earth|              2|
# |   Blackpowder Games|              2|
# |            Bulbware|              2|
# |          VoxelStorm|              2|
# |              xinoro|              2|
# |Dolores Entertain...|              2|
# |         Ideum, Inc.|              2|
# |         Hippomancer|              2|
# |                   -|              2|
# |      Charlies Games|              2|
# |     Inventive Dingo|              2|
# |      Fishing Cactus|              2|
# |      Zillion Whales|              2|
# |Nevercenter Ltd. Co.|              2|
# |         Tiger Style|              2|
# |            Enitvare|              2|
# |          Team Kryll|              2|
# |         Kajak Games|              2|
# |             MLB.com|              2|
# |        Shiver Games|              2|
# |       Curve Studios|              2|
# |           Mandlebar|              2|
# |      Cheerful Ghost|              2|
# | Technomancy Studios|              2|
# |           DarkElite|              2|
# |Aeonic Entertainment|              2|
# |    Ripatti Software|              2|
# |        Wonderstruck|              2|
# |         DiezelPower|              2|
# |    Modulaatio Games|              2|
# |       Moment Studio|              2|
# |Subatomic Studios...|              2|
# |        Pixelz Games|              2|
# |          Panic Inc.|              2|
# |         Three Rings|              2|
# |       Badland Games|              2|
# |Archive Entertain...|              2|
# |          Grip Games|              2|
# |    DanielDavisGames|              2|
# | Eyebrow Interactive|              2|
# |    Psydra Games LLC|              2|
# |       Spasman Games|              2|
# |         BigSims.com|              2|
# |   Winged Pixel Inc.|              2|
# |  New Star Games Ltd|              2|
# |      3f Interactive|              2|
# |       Prism Studios|              2|
# |               Array|              2|
# |    Dzung Phung Dinh|              2|
# |Dark Castle Software|              2|
# |  Incandescent Games|              2|
# |              SiBear|              2|
# |      CleanWaterSoft|              2|
# |     Dovetail Games |              2|
# |Doctor Entertainment|              2|
# |   Snow Cannon Games|              2|
# |          Image&Form|              2|
# |       IQ Publishing|              2|
# |Full Control Studios|              2|
# |         UnitedIndie|              2|
# |       Keinart Lobre|              2|
# |       MidBoss, LLC.|              2|
# | Vertigo Gaming Inc.|              2|
# |           KarjaSoft|              2|
# |  BA Productions LLC|              2|
# |   UltraShock Gaming|              2|
# |    Raphael Gervaise|              2|
# |    Sinclair Strange|              2|
# |    Triangle Studios|              2|
# |  ElevenSeventy, LLC|              2|
# |Divergent Game St...|              2|
# |          Heartomics|              2|
# | Vitaly Rekubratskiy|              2|
# |            Bulkypix|              2|
# |       Frogdice, Inc|              2|
# |Scrap Yard Produc...|              2|
# |Above and Beyond ...|              2|
# |            Treasure|              2|
# |         Talentplace|              2|
# |              Treexy|              2|
# |      Xiotex Studios|              2|
# |Handelabra Games ...|              2|
# |              Sogoal|              2|
# |  Farsky Interactive|              2|
# |  Giorgi Abelashvili|              2|
# |         Shiro Games|              2|
# |Batholith Enterta...|              2|
# |         GalaxyTrail|              2|
# | Rubicon Development|              2|
# |       HandMade Game|              2|
# |             AKGames|              2|
# |           IndieGala|              2|
# |             Pilgway|              2|
# |    Supergiant Games|              2|
# |        Team Reptile|              2|
# |   The Revills Games|              2|
# |          Code}{atch|              2|
# |          Pyrodactyl|              2|
# |Vasara Entertainment|              2|
# |      Zueira Digital|              2|
# |        RGCD.DEV LTD|              2|
# |         PolyDigital|              2|
# |Skirmish Entertai...|              2|
# |Propelled Bird So...|              2|
# |The Fine Young Ca...|              2|
# |    isTom Games Kft.|              2|
# |     THE BROTHERHOOD|              2|
# |      Varkian Empire|              2|
# |   Gato Salvaje S.L.|              2|
# |          Agent Mega|              2|
# |      Dancing Devils|              2|
# |       Q-Games, Ltd.|              2|
# |   Specialbit Studio|              2|
# |  Tasty Stewdios LLC|              2|
# |        Bugbyte Ltd.|              2|
# | Snapshot Games Inc.|              2|
# |Holgersson Entert...|              2|
# |         Date Nighto|              2|
# |        Etter Studio|              2|
# |              Crytek|              2|
# |          Multi-Form|              2|
# | Night Node Software|              2|
# |Marmalade Technol...|              2|
# |         Campo Santo|              2|
# |         Hammer Labs|              2|
# | Nomad Games Limited|              2|
# |         Kloonigames|              2|
# |        Okugi Studio|              2|
# |       Chris Johnson|              2|
# |Metaware Limited,...|              2|
# |          Casualogic|              2|
# |       Lantana Games|              2|
# |    South East Games|              2|
# |Dark Roast Entert...|              2|
# |           Eutechnyx|              2|
# |            Retrific|              2|
# |         WRF Studios|              2|
# |              Untame|              2|
# |       Sergey Bobrov|              2|
# |     Red Mount Media|              2|
# |      Studio Namaapa|              2|
# |             Ravegan|              2|
# |    Psytec Games Ltd|              2|
# |      Digital Tribes|              2|
# |        Mechabit Ltd|              2|
# |     PixelTail Games|              2|
# |Craze Creative St...|              2|
# |        Philip Royer|              2|
# |          KintoGames|              2|
# |     Undead Labs LLC|              2|
# |        Kitfox Games|              2|
# |Stone Monkey Studios|              2|
# |        Marmoset LLC|              2|
# |        René Bühling|              2|
# |   Simon Says: Play!|              2|
# |       MyLifeGame.RU|              2|
# |Game Studio Abrah...|              2|
# | Emmanuel Salva Cruz|              2|
# |    Holotech Studios|              2|
# |           Evan Todd|              2|
# |      Barkalar Games|              2|
# |  Seraphim Creations|              2|
# |       Playdek, Inc.|              2|
# |Minddesk Software...|              2|
# |Idea Factory Inte...|              2|
# |       Herrero Games|              2|
# |     Headless Wizard|              2|
# |         Unika Games|              2|
# |                none|              2|
# |Smartly Dressed G...|              2|
# |StarWraith 3D Gam...|              2|
# |              Fridge|              2|
# |            Huy Phan|              2|
# |        NewWestGames|              2|
# |      Behold Studios|              2|
# |          Erichermit|              2|
# |     Moonlit Studios|              2|
# |  Stolen Couch Games|              2|
# |          Sabi Games|              2|
# |           Gamerizon|              2|
# |      Relevant Games|              2|
# |Flying Cafe for S...|              2|
# |            ACE Team|              2|
# |Out of the Park D...|              2|
# |        Recoil Games|              2|
# |Zombie Orpheus En...|              2|
# |               Squad|              2|
# | The Shoebox Diorama|              2|
# |        Studio Paint|              2|
# |Forgotten Empires...|              2|
# |      Force Of Habit|              2|
# |  Future Proof Games|              2|
# |        Eko Software|              2|
# |Dingaling Product...|              2|
# |            GoodVole|              2|
# |      Auroch Digital|              2|
# |         Dustin Gunn|              2|
# |        JoyBits, LTD|              2|
# |      Airys Software|              2|
# |      Artizens, Inc.|              2|
# |             Draknek|              2|
# |         Lumenox ehf|              2|
# |  Source Studio Ltd.|              2|
# | Pen and Sword Games|              2|
# | Relentless Software|              2|
# |New Blood Interac...|              2|
# |Math Nerd Product...|              2|
# |       Real Dynamics|              2|
# |On The Level Game...|              2|
# |         Tikipod Ltd|              2|
# |      Walter Machado|              2|
# |     Die Gute Fabrik|              2|
# |           Sam Albon|              2|
# |Cartoon Network G...|              2|
# |         Number None|              2|
# |     Studio Wildcard|              2|
# |          NEKO WORKs|              2|
# |    Felix Wunderlich|              2|
# |  Namco Bandai Games|              2|
# |Snipefish Enterta...|              2|
# |          Ninja Kiwi|              2|
# |           Pixelatto|              2|
# |           No Goblin|              2|
# |       Santa Ragione|              2|
# |     Infamous Quests|              2|
# |    Final Form Games|              2|
# |         Tayfun Tuna|              2|
# |     increpare games|              2|
# | No Pest Productions|              2|
# |  Evil Twin Artworks|              2|
# |               Faton|              2|
# |       Longbow Games|              2|
# |     Firefly Studios|              2|
# |  RSUPPORT Co., LTD.|              2|
# |All Seeing Eye Games|              2|
# |             Gamious|              2|
# |         Tom Johnson|              2|
# |            Hydezeke|              2|
# |  GSProductions Ltd.|              2|
# | CBE Software s.r.o.|              2|
# |GameIndica Entert...|              2|
# |        eMedia Music|              2|
# |Electroplasmatic ...|              2|
# |       Professor Why|              2|
# |              Encore|              2|
# |        KrupinskiArt|              2|
# |               VROOM|              2|
# |          RiftyGames|              2|
# |            Neotenia|              2|
# |Iron Galaxy Studi...|              2|
# |Naked Sky Enterta...|              2|
# |           Channel 4|              2|
# | Recotechnology S.L.|              2|
# |   Robot Loves Kitty|              2|
# |Big Ant Studios (...|              2|
# |   SimplexGameStudio|              2|
# |          Trichotomy|              2|
# |   Wax Lyrical Games|              2|
# | Psychotic Psoftware|              2|
# |Born Ready Games ...|              2|
# |                  NA|              2|
# |          SmashGames|              2|
# |           Studio 48|              2|
# |           3D Realms|              2|
# |      The Secret Pie|              2|
# |     Brushfire Games|              2|
# |              Aspyr |              2|
# |              Pezomi|              2|
# |   The Working Parts|              2|
# |  Cherry Co. Studios|              2|
# | WINGED SAKURA GAMES|              2|
# |        Ysbryd Games|              2|
# |       Llamasoft LTD|              2|
# |Groupees Interactive|              2|
# |       Heart Machine|              2|
# |    Crankshaft Games|              2|
# |       HD Publishing|              2|
# |    Timedrop Studios|              2|
# |     BeautiFun Games|              2|
# |     Fireproof Games|              2|
# | Power Up to Maximum|              2|
# |  AtomicTorch Studio|              2|
# |   Wakeskater Studio|              2|
# |    Mayhem Games USA|              2|
# |Pinkerton Road St...|              2|
# |Render System Ent...|              2|
# ...
# |        Artem Bondin|              1|
# |    One Wheel Studio|              1|
# | Silver Dollar Games|              1|
# |Seaside Digital Arts|              1|
# |Anteater Games, E...|              1|
# |      Underdog Games|              1|
# |Heliocentric Studios|              1|
# |            Whalegun|              1|
# |    ArrowGroundGames|              1|
# |       Adam McLellan|              1|
# |       Nick Donnelly|              1|
# | Flaming Pumpkin Ltd|              1|
# |               Kiddy|              1|
# |        Bigger Boat |              1|
# |           2K Games |              1|
# |       Alex Woodcock|              1|
# |Skybound Interactive|              1|
# |  Xiotex Studios Ltd|              1|
# | Blazing Griffin Ltd|              1|
# |            Tekitown|              1|
# |      Curious Planet|              1|
# |      Ground Shatter|              1|
# |   Bubble Head Games|              1|
# |  Noyer Game Studios|              1|
# |       IonFX Studios|              1|
# |     Immersive Douro|              1|
# |   Mighty Fox Studio|              1|
# |   Spellbind Studios|              1|
# | McMagic Productions|              1|
# |       Mastiff Games|              1|
# |         House House|              1|
# |      MeDungeon Ltd.|              1|
# |  Human Head Studios|              1|
# |Descendent Studio...|              1|
# |Blackthorn Media,...|              1|
# |            Romenics|              1|
# |    OpenXcell Studio|              1|
# |            adamgryu|              1|
# |        Binary Cocoa|              1|
# |   Brainy Studio LLC|              1|
# |   Reverb Triple XP |              1|
# |Double Plus Good ...|              1|
# |     Sinister Design|              1|
# |  Wheat Muffin Games|              1|
# |iRacing.com Motor...|              1|
# |              Jarbit|              1|
# |          Farjay.com|              1|
# |       Stately Snail|              1|
# |    Eurovideo Medien|              1|
# |         Thing Trunk|              1|
# |      Jackson Clarke|              1|
# |     5 Lives Studios|              1|
# |    Light Step Games|              1|
# |   Beam Team Pty Ltd|              1|
# |Revival Productio...|              1|
# |       Lorenzo Games|              1|
# |Radioactive-Software|              1|
# |           Guy Godin|              1|
# |      Nurgo Software|              1|
# |           Thrillion|              1|
# |          Abrakam SA|              1|
# |  Hunted Cow Studios|              1|
# |Culture Attack St...|              1|
# |  Zombie Cow Studios|              1|
# |             Super63|              1|
# |         Mizar Games|              1|
# |          Astrosnout|              1|
# |         Adam Mowery|              1|
# |Ludosity Interactive|              1|
# |          JAVELIN OÜ|              1|
# |Harmonix Music Sy...|              1|
# |Machine Bear® Sof...|              1|
# |              sxpenx|              1|
# |          Mark Chong|              1|
# |            Kerberos|              1|
# |        Enormous Elk|              1|
# |       Alan Edwardes|              1|
# |         SFS Studios|              1|
# |        Pathea Games|              1|
# |        Rudder Games|              1|
# |    Playa Games GmbH|              1|
# |   BlackFoot Studios|              1|
# |        AndrewWatt96|              1|
# |        Singe Studio|              1|
# |           iPi Soft |              1|
# |    Vivid Games S.A.|              1|
# |Cake Collective G...|              1|
# |           Nuke Nine|              1|
# |         Radiangames|              1|
# |   Gato Salvaje S.L.|              1|
# |         Sonic Sloth|              1|
# |                EVGA|              1|
# |              Hut 90|              1|
# |            dotBunny|              1|
# |           WJLE GAME|              1|
# |         KBros Games|              1|
# |    ASBO Interactive|              1|
# |   benmakesgames.com|              1|
# |           Sparpweed|              1|
# |              MAGICS|              1|
# |          Wevr, Inc.|              1|
# |      Flatline games|              1|
# |        David Teruel|              1|
# |Creative Storm En...|              1|
# |        SunRay Games|              1|
# |Scientifically Pr...|              1|
# |           tinybuild|              1|
# |         CydoniaGate|              1|
# | Nodbrim Interactive|              1|
# |         Evil Aliens|              1|
# |        FUN Creators|              1|
# |    Spark Plug Games|              1|
# |Abstract Tree Studio|              1|
# |        Tim Sullivan|              1|
# |         Substantial|              1|
# |        Neomex-Games|              1|
# |            IllFonic|              1|
# |            m07games|              1|
# |      Dragon's Games|              1|
# |    Other Kind Games|              1|
# | BioWare Corporation|              1|
# |Ground Control St...|              1|
# |Simple Designs So...|              1|
# |QianZhiHuDong Net...|              1|
# |      Dimmdrive Inc.|              1|
# |MindShaft Games, LLC|              1|
# |Codename Entertai...|              1|
# |               Dan_D|              1|
# |               MKLab|              1|
# |            GG-Works|              1|
# |          Soul Forge|              1|
# |        Petite Games|              1|
# |            Stardock|              1|
# |     Hailstorm Games|              1|
# |         Chris Chung|              1|
# | DuCats Games Studio|              1|
# |        Lewis Bergin|              1|
# |       2Brains Games|              1|
# |       Stamina-Games|              1|
# |     SignHead Studio|              1|
# |    grapefrukt games|              1|
# |   Creaky Corpse Ltd|              1|
# |               Nozon|              1|
# |           Miolhr SM|              1|
# |     Animakemu Games|              1|
# |    Delirium Studios|              1|
# |Little Worlds Int...|              1|
# |     Wizard Fu Games|              1|
# |      Rhizome Games™|              1|
# |    Stygian Software|              1|
# |          Crecatsoft|              1|
# |       Kirill Belman|              1|
# |    Reventador Games|              1|
# |         energy milk|              1|
# |      Angry Cat Ltd.|              1|
# |      Cemil Tasdemir|              1|
# |Cloudhead Games ltd.|              1|
# |Goldhawk Interactive|              1|
# |        Mastiff LLC.|              1|
# |      Teeworlds Team|              1|
# |       Heydeck Games|              1|
# |          Wang Liwen|              1|
# |         CP Decision|              1|
# |      ShadowShifters|              1|
# |            3 Fright|              1|
# |          Seattletek|              1|
# |         Adminde Ltd|              1|
# |        Balcony Team|              1|
# |   Phosfiend Systems|              1|
# | Oovee® Game Studios|              1|
# |        Clever-Plays|              1|
# |      E.Q. Games LLC|              1|
# |  Zanrai Interactive|              1|
# |Dovetail Games - ...|              1|
# |The Lo-Fi Apocaly...|              1|
# |         Kiemura Ltd|              1|
# |          BitFinity |              1|
# |       Headup Games |              1|
# |        Discovr Labs|              1|
# |    Giant Enemy Labs|              1|
# |   Triangular Pixels|              1|
# |  Crowbar Collective|              1|
# |       Evan Tognotti|              1|
# |         Tiny Utopia|              1|
# |     The Indie Forge|              1|
# |EuroVideo Medien ...|              1|
# | Talking About Media|              1|
# |Brilliant Skies Ltd.|              1|
# |             Halycon|              1|
# |         Bitbox Ltd.|              1|
# |         Varia Games|              1|
# |      Industry Games|              1|
# |    Archetype Global|              1|
# |        Bitbox Games|              1|
# |       FlexileStudio|              1|
# |     Developers Pack|              1|
# |  Brainwashing games|              1|
# |               Cylne|              1|
# |           WnMStudio|              1|
# |         Just a Game|              1|
# |      Coty Getzelman|              1|
# |         Ferocity 2D|              1|
# |        AndrewDrumov|              1|
# |       Nerd Monkeys®|              1|
# |    Bloodwolf Studio|              1|
# |  The Glitch Factory|              1|
# |       Thomas Konkol|              1|
# |             Dev Arc|              1|
# |         Pop Sandbox|              1|
# |   Zadzen Games Ltd.|              1|
# |Unknown Worlds En...|              1|
# |     Benjamin Bryant|              1|
# |Broken Window Stu...|              1|
# |             Deck13 |              1|
# |           Altfuture|              1|
# |            Fakedice|              1|
# |        Icetesy SPRL|              1|
# |      Cameron Baxter|              1|
# |    Cooply Solutions|              1|
# |Ceiba Software an...|              1|
# |      Namazu Studios|              1|
# |Games by Robert, LLC|              1|
# |            Morphiks|              1|
# |         Rovio Stars|              1|
# |        Questtracers|              1|
# |    Alex Jedraszczak|              1|
# |              COWCAT|              1|
# |            Shovsoft|              1|
# |           Colopl NI|              1|
# |      Goblinz Studio|              1|
# |     Clarus Victoria|              1|
# |    Milestone S.r.l.|              1|
# |Buff Studio Co.,Ltd.|              1|
# |   Screeching Wizard|              1|
# | Zanza Studios, LLC.|              1|
# |TawStudio Enterta...|              1|
# |             Kuchalu|              1|
# |         Homa Design|              1|
# |        Wild Rooster|              1|
# |         Vector Unit|              1|
# |      Atypical Games|              1|
# |      The Quadsphere|              1|
# |    Masangsoft, Inc.|              1|
# |   Day Dreamer Games|              1|
# | Batterystaple Games|              1|
# |         XProd Games|              1|
# |Napoleon Games, s...|              1|
# |          Burnin Ape|              1|
# |        Will O'Neill|              1|
# |      PillowPigGames|              1|
# |    Crunching Koalas|              1|
# |Celsius Game Studios|              1|
# |Bat Country Games...|              1|
# |       Johannes Eski|              1|
# |    Devovler Digital|              1|
# |Nemoria Entertain...|              1|
# |           HFM Games|              1|
# |         Rocket Jump|              1|
# |           MonkeyMaw|              1|
# |           Not Magic|              1|
# |        Loren Lemcke|              1|
# |        Radial Games|              1|
# |        sparsevector|              1|
# |   4-Panel Footprint|              1|
# |  ByteTrail Software|              1|
# |       Woodsy Studio|              1|
# |               RigIT|              1|
# |            Overflow|              1|
# |        Dan  Walters|              1|
# |   Wild Games Studio|              1|
# |Entrada Interacti...|              1|
# |       Gamestarter's|              1|
# |Drowning Monkeys ...|              1|
# |SolidFace Paramet...|              1|
# |         Ketos Games|              1|
# |       Innerspace VR|              1|
# |      Mason Lindroth|              1|
# |     Underbite Games|              1|
# |Blooming Buds Studio|              1|
# |     Frima Originals|              1|
# |     Sauropod Studio|              1|
# |    HyperBerry Games|              1|
# |    Nikolai Patrakov|              1|
# |Strangely Named S...|              1|
# |Vishnu Vadakke Pa...|              1|
# |     Triskelia Games|              1|
# |  Fish Factory Media|              1|
# |           Dan Games|              1|
# |    Carmine T. Guida|              1|
# |          iNDEE SOLO|              1|
# |      SmallGreenHill|              1|
# |    Peltast Software|              1|
# |astragon Software...|              1|
# |GameMill Entertai...|              1|
# |Tripwire Interact...|              1|
# |Queen Birdface Pr...|              1|
# |           JH12world|              1|
# |          Permadeath|              1|
# |          Axel Shokk|              1|
# |         Lo-Fi Games|              1|
# |        ESTsoft Inc.|              1|
# |     Prototype Games|              1|
# |         Semen Rodin|              1|
# |    Playful Art, LLC|              1|
# |          GameLooper|              1|
# |          Luke Haney|              1|
# |       Baroque Decay|              1|
# |          Qwiboo Ltd|              1|
# |       Condition One|              1|
# |    Apparition Games|              1|
# |    PD Design Studio|              1|
# |   White Clover Inc.|              1|
# |      Carlotta Tatti|              1|
# |                 2K |              1|
# |           EfimovMax|              1|
# |         Not Doppler|              1|
# |         Team Signal|              1|
# |     Endgame Studios|              1|
# |             ShaunJS|              1|
# |         Petroglyph |              1|
# |       Conflux Games|              1|
# |     Pirate Software|              1|
# |  Spiderling Studios|              1|
# |Profenix Studio SRLS|              1|
# |            AOS GAME|              1|
# |vertex4 entertain...|              1|
# |           Icy Donut|              1|
# |           SkyGoblin|              1|
# |     1C Game Studios|              1|
# |  gnifrebel Games UG|              1|
# |        Andrés Calva|              1|
# |  Smashball Labs LLC|              1|
# |              Yokcos|              1|
# |             Playrix|              1|
# |      Relative Games|              1|
# |            Anothink|              1|
# |        PolarityFlow|              1|
# |       House of Wire|              1|
# | Red Wasp Design Ltd|              1|
# |        Lucas Parise|              1|
# |         Kiz Studios|              1|
# |       Cross-Product|              1|
# |  YouNeedABudget.com|              1|
# |Dovetail Games -T...|              1|
# |        Axolot Games|              1|
# |       Retro Dreamer|              1|
# |Rocketeer Games S...|              1|
# |             Spotkin|              1|
# |       Zero Dollarz |              1|
# |            17Studio|              1|
# |      Concrete Games|              1|
# |   Vault Interactive|              1|
# |             Phyrnna|              1|
# |            HCPGames|              1|
# |        Mixed In Key|              1|
# |Paranoid Productions|              1|
# |     Machine Studios|              1|
# | Micro Factory Games|              1|
# |Doragon Entertain...|              1|
# |Bandai Namco Ente...|              1|
# |            Aartform|              1|
# |         Aric Morrow|              1|
# |     Freeze Tag Inc.|              1|
# |           Skygoblin|              1|
# |        AwesomeBlade|              1|
# |       Robot Invader|              1|
# |   Membraine Studios|              1|
# |          Nekki GmbH|              1|
# |         Atelier 801|              1|
# |       Pinkapp Games|              1|
# |        Bludgeonsoft|              1|
# |     Firebrand Games|              1|
# |    Toge Productions|              1|
# |       Erotes Studio|              1|
# |    Geek Sloth Games|              1|
# |Ron McDowell and ...|              1|
# |                Sørb|              1|
# |          ColloseusX|              1|
# |             Bugbear|              1|
# |        Frozen Flame|              1|
# |        Maurice Pape|              1|
# |     Tamarin Studios|              1|
# |    OM ENTERTAINMENT|              1|
# | Flatbox Studios LLC|              1|
# |Stone Pixel Games...|              1|
# |     Megastorm Games|              1|
# |    IronDrop Studios|              1|
# |    Vectorpark, Inc.|              1|
# |  Gaming Cats Studio|              1|
# |Regimental Chess ...|              1|
# |Gravity Games UG ...|              1|
# |             Droog71|              1|
# |   Octoshark Studios|              1|
# |        Happion Labs|              1|
# |      wefiends, Inc.|              1|
# |   Radial Games Corp|              1|
# |Neo Red Entertain...|              1|
# |             NTTGame|              1|
# |         Independent|              1|
# |           FlukeDude|              1|
# |          3100 games|              1|
# |        Vortal Storm|              1|
# |     Barnstorm Games|              1|
# |     Quickfire Games|              1|
# |          SaintBunny|              1|
# |Cantina Games and...|              1|
# |     LigaGamesStudio|              1|
# |Lazy Games Studio...|              1|
# |XPEC Entertainmen...|              1|
# +--------------------+---------------+

# %% [markdown]
# #### Observation
# The highest count is given by the null value, which I assume represents the indie publishers.

# %%
# Number of games per genre
df_games_genres.createOrReplaceTempView("genres")
games_per_genre = sqlContext.sql("""
    SELECT Genre, COUNT(appid) as Genre_Count
    FROM genres
    GROUP BY Genre
    ORDER BY Genre_Count desc
""")

games_per_genre.show(games_per_genre.count())
# Out:
# +--------------------+-----------+
# |               Genre|Genre_Count|
# +--------------------+-----------+
# |               Indie|       7982|
# |              Action|       7126|
# |           Adventure|       4517|
# |            Strategy|       3953|
# |              Casual|       3939|
# |          Simulation|       3870|
# |                 RPG|       3147|
# |        Free to Play|       1172|
# |        Early Access|        901|
# |Massively Multipl...|        748|
# |              Racing|        619|
# |              Sports|        604|
# |Design & Illustra...|        240|
# |           Utilities|        207|
# |      Web Publishing|        146|
# |Animation & Modeling|        112|
# |    Audio Production|        112|
# |   Software Training|         82|
# |           Education|         73|
# |    Video Production|         69|
# |       Photo Editing|         46|
# |          Accounting|          4|
# +--------------------+-----------+

# %% [markdown]
# #### Observation
#
# As I suspected, Indie games has the highest count followed by Action games with small difference.

# %% [markdown]
# ### 2.7 Find day and hour when most new accounts were created
#
# It will be based only on Player_Summaries table. I will find the highest count of newly created accounts based on the day only, the hour only, and the datetime.

# %%
# Remove null values
df_player_summaries = df_player_summaries.na.drop(subset=["timecreated"])
df_player_summaries.createOrReplaceTempView("player_summaries")

# %%
# Find a day when most new accounts were created
sqlContext.sql("""
  SELECT to_date(timecreated) as Start_Date, 
         to_date(date_add(timecreated,1)) as End_Date, 
         COUNT(steamid) as Count_New_Accounts
  FROM player_summaries
  WHERE timecreated >= to_date(timecreated) and timecreated < to_date(date_add(timecreated,1))
  GROUP BY Start_Date
  ORDER BY Count_New_Accounts desc
  LIMIT 5
""").show()
# Out:
# +----------+----------+------------------+
# |Start_Date|  End_Date|Count_New_Accounts|
# +----------+----------+------------------+
# |2012-12-25|2012-12-26|              3682|
# |2012-11-28|2012-11-29|              3366|
# |2012-12-26|2012-12-27|              2691|
# |2012-12-24|2012-12-25|              2634|
# |2012-12-22|2012-12-23|              2508|
# +----------+----------+------------------+

# %% [markdown]
# The day when most new accounts were created is between 2012/12/25 and 2012/12/26 with 3682 accounts newly created. Interestingly, five top results are all from year 2012 and between the end of November to the end of December on that year.

# %%
# Find the hour when most new accounts were created
sqlContext.sql("""
  SELECT hour(timecreated) as Start_Hour, 
         (hour(timecreated)+1) as End_Hour, 
         COUNT(steamid) as Count_New_Accounts
  FROM player_summaries
  GROUP BY Start_Hour
  ORDER BY Count_New_Accounts desc
  LIMIT 5
""").show()
# Out:
# +----------+--------+------------------+
# |Start_Hour|End_Hour|Count_New_Accounts|
# +----------+--------+------------------+
# |        10|      11|             14950|
# |        11|      12|             14660|
# |         9|      10|             14368|
# |         8|       9|             14167|
# |        12|      13|             13975|
# +----------+--------+------------------+

# %% [markdown]
# From the query, we could see that between 10AM to 11AM is the period when there were the highest number of newly created account. Moreover, we could say that most people created their account in the morning between 8AM to 13PM.

# %% [markdown]
# Finally, to find the datetime when most new accounts were created, I will extend the player summaries dataframe to include rounded hour 'timecreated' column as 'start_timecreated' and rounded hour plus 1 'timecreated' column as 'end_timecreated'.

# %%
df_player_summaries = df_player_summaries.withColumn("start_timecreated", 
    SqlF.from_unixtime(SqlF.unix_timestamp("timecreated","yyyy-MM-dd'T'HH:mm:ss"),"yyyy-MM-dd HH:00:00"))

df_player_summaries = df_player_summaries.withColumn("end_timecreated", 
    SqlF.from_unixtime(SqlF.unix_timestamp("timecreated","yyyy-MM-dd'T'HH:mm:ss") + 3600,"yyyy-MM-dd HH:00:00"))

df_player_summaries.createOrReplaceTempView("extended_player_summaries")

# %%
# Find the datetime when most new accounts were created
sqlContext.sql("""
  SELECT start_timecreated as Start_Time, 
         end_timecreated as End_Time, 
         COUNT(steamid) as Count_New_Accounts
  FROM extended_player_summaries
  WHERE timecreated >= start_timecreated and timecreated < end_timecreated
  GROUP BY Start_Time, End_Time
  ORDER BY Count_New_Accounts desc
  Limit 5
""").show()
# Out:
# +-------------------+-------------------+------------------+
# |         Start_Time|           End_Time|Count_New_Accounts|
# +-------------------+-------------------+------------------+
# |2012-12-25 10:00:00|2012-12-25 11:00:00|               292|
# |2012-12-25 08:00:00|2012-12-25 09:00:00|               279|
# |2012-12-25 11:00:00|2012-12-25 12:00:00|               230|
# |2012-11-28 11:00:00|2012-11-28 12:00:00|               219|
# |2012-11-28 10:00:00|2012-11-28 11:00:00|               216|
# +-------------------+-------------------+------------------+

# %% [markdown]
# It was on Christmas 2012 when there were a lot of newly created accounts in the morning, especially between 10AM and 11AM.

# %% [markdown]
# #### Observation
#
# There might be special events that occurred between the end of November 2012 to the end of December 2012 with the peak of the event was on the Christmas Day (December 25th, 2012). It is concluded this way as the density of newly created accounts is considerably high on that period.

# %% [markdown]
# ## 3. Rating Prediction Model
#
# In this section, I will try to build a model to predict the rating of a game.

# %%
from pyspark.ml.feature import OneHotEncoder, StringIndexer, VectorAssembler
from pyspark.ml.regression import LinearRegression, DecisionTreeRegressor
from pyspark.ml.evaluation import RegressionEvaluator

# %%
# Read App_ID_Info.csv
file_app = "steam_gaming_small\App_ID_Info.csv"
df_app = sqlContext.read.format("csv").option("inferSchema", 
                                                           True).option("header", True).load(file_app)

# %% [markdown]
# The rating of a game is affected by some factors outside of the gameplay. Some of those factors are the price, age requirement, multiplayer feature, genre, publishers and developer. Therefore, we need to combine several table to get the field that we need.

# %%
df_games_publishers.createOrReplaceTempView("publishers")
df_games_genres.createOrReplaceTempView("genres")
df_games_developers.createOrReplaceTempView("developers")
df_app.createOrReplaceTempView("application")

# %%
df_application = sqlContext.sql("""
  SELECT application.Price, application.Required_Age, application.Is_multiplayer
  , genres.Genre, publishers.Publisher, developers.Developer, application.Rating
  FROM application LEFT JOIN genres
  ON application.appid == genres.appid
  LEFT JOIN publishers
  ON application.appid == publishers.appid
  LEFT JOIN developers
  ON application.appid == developers.appid
  WHERE application.Rating != -1
""")

# Drop NULL values
df_application = df_application.na.drop()

# %% [markdown]
# Along with removing rows with NULL values, observations with rating equals to -1 are removed as well as those observations would hinder the training of the model. (-1 is equal to not rated yet)

# %%
df_application.printSchema()
# Out:
# root
#  |-- Price: string (nullable = true)
#  |-- Required_Age: integer (nullable = true)
#  |-- Is_multiplayer: integer (nullable = true)
#  |-- Genre: string (nullable = true)
#  |-- Publisher: string (nullable = true)
#  |-- Developer: string (nullable = true)
#  |-- Rating: string (nullable = true)

# %% [markdown]
# We can see that Price and Rating have type of string, but we want them to be numerical. Therefore, below is a step to change the column type.

# %%
df_application = df_application.withColumn('Price', df_application.Price.cast('float'))
df_application = df_application.withColumn('Rating', df_application.Rating.cast('integer'))

# %%
df_application.printSchema()
# Out:
# root
#  |-- Price: float (nullable = true)
#  |-- Required_Age: integer (nullable = true)
#  |-- Is_multiplayer: integer (nullable = true)
#  |-- Genre: string (nullable = true)
#  |-- Publisher: string (nullable = true)
#  |-- Developer: string (nullable = true)
#  |-- Rating: integer (nullable = true)

# %%
df_application.show(5)
# Out:
# +-----+------------+--------------+--------------------+----------------+--------------------+------+
# |Price|Required_Age|Is_multiplayer|               Genre|       Publisher|           Developer|Rating|
# +-----+------------+--------------+--------------------+----------------+--------------------+------+
# |  0.0|           0|             1|Massively Multipl...|         Ubisoft|Ivory Tower in co...|    71|
# |  0.0|           0|             1|              Racing|         Ubisoft|Ivory Tower in co...|    71|
# |  0.0|           0|             1|              Action|         Ubisoft|Ivory Tower in co...|    71|
# |  0.0|           0|             0|           Adventure|Frictional Games|    Frictional Games|    67|
# |  0.0|           0|             0|               Indie|Frictional Games|    Frictional Games|    67|
# +-----+------------+--------------+--------------------+----------------+--------------------+------+
# only showing top 5 rows

# %% [markdown]
# Now we have the DataFrame to predict the rating. However, there are three categorical features: Genre, Publisher and Developer that we need to preprocess into one hot representation before modelling.

# %%
def processCategorical(dataFrame, inputColIndex, outputColIndex, outputColOneHot):
    stringIndexer = StringIndexer(inputCol=inputColIndex, outputCol=outputColIndex)
    model = stringIndexer.fit(dataFrame)
    indexed = model.transform(dataFrame)
    encoder = OneHotEncoder(dropLast=False, inputCol=outputColIndex, outputCol=outputColOneHot)
    encoded = encoder.transform(indexed)
    
    return encoded

# %%
df_application_transformed = processCategorical(df_application, 'Genre', 'Genre_index', 'Genre_vec')
df_application_transformed = processCategorical(df_application_transformed, 'Publisher', 'Publisher_index', 'Publisher_vec')
df_application_transformed = processCategorical(df_application_transformed, 'Developer', 'Developer_index', 'Developer_vec')

# %%
df_application_transformed.printSchema()
# Out:
# root
#  |-- Price: float (nullable = true)
#  |-- Required_Age: integer (nullable = true)
#  |-- Is_multiplayer: integer (nullable = true)
#  |-- Genre: string (nullable = true)
#  |-- Publisher: string (nullable = true)
#  |-- Developer: string (nullable = true)
#  |-- Rating: integer (nullable = true)
#  |-- Genre_index: double (nullable = false)
#  |-- Genre_vec: vector (nullable = true)
#  |-- Publisher_index: double (nullable = false)
#  |-- Publisher_vec: vector (nullable = true)
#  |-- Developer_index: double (nullable = false)
#  |-- Developer_vec: vector (nullable = true)

# %% [markdown]
# Now, we have the data we need to start modelling. As we want to predict rating, this will be a regression problem. First, let us try the linear regression method.

# %% [markdown]
# ### 3.1 Linear Regression

# %%
# Prepare the Features and Label
vectorAssembler = VectorAssembler(inputCols = ['Price', 'Required_Age', 'Is_multiplayer', 
                                               'Genre_index', 'Publisher_index', 'Developer_index'], 
                                  outputCol = 'Features')
df_application_transformed_vec = vectorAssembler.transform(df_application_transformed)
df_application_transformed_vec = df_application_transformed_vec.select(['Features', 'Rating'])
df_application_transformed_vec.show(5)
# Out:
# +--------------------+------+
# |            Features|Rating|
# +--------------------+------+
# |[0.0,0.0,1.0,10.0...|    71|
# |[0.0,0.0,1.0,7.0,...|    71|
# |(6,[2,5],[1.0,201...|    71|
# |[0.0,0.0,0.0,3.0,...|    67|
# |[0.0,0.0,0.0,1.0,...|    67|
# +--------------------+------+
# only showing top 5 rows

# %%
# Split into training set and testing set
splits = df_application_transformed_vec.randomSplit([0.7, 0.3])
train_df = splits[0]
test_df = splits[1]

# %%
lr = LinearRegression(featuresCol = 'Features', labelCol='Rating', maxIter=10, regParam=0.1, elasticNetParam=0.1)
lr_model = lr.fit(train_df)

# %%
trainingSummary = lr_model.summary

print("Train RMSE: %f" % trainingSummary.rootMeanSquaredError)
print("Train R2: %f" % trainingSummary.r2)
# Out:
# Train RMSE: 10.608134
# Train R2: 0.063361

# %% [markdown]
# The linear regression model could not perform well. The R2 metric is very low, meaning that the model cannot explain the Rating.

# %%
lr_predictions = lr_model.transform(test_df)
lr_predictions.show(10)
# Out:
# +--------------------+------+-----------------+
# |            Features|Rating|       prediction|
# +--------------------+------+-----------------+
# |(6,[0,4],[19.9899...|    91|74.63756906023482|
# |(6,[0,4],[19.9899...|    91|74.63756906023482|
# |(6,[0,4],[19.9899...|    91|74.62878065969153|
# |(6,[0,4],[39.9900...|    72|76.60976954904056|
# |(6,[0,5],[9.98999...|    82| 73.6154480174183|
# |(6,[0,5],[9.98999...|    91|73.24113848103666|
# |(6,[0,5],[9.98999...|    72|69.39345662911357|
# |(6,[0,5],[9.98999...|    58|69.01914709273193|
# |(6,[0,5],[19.9899...|    86|73.39605127855022|
# |(6,[2,5],[1.0,450...|    85|71.23140581998685|
# +--------------------+------+-----------------+
# only showing top 10 rows

# %%
lr_evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="Rating",metricName="r2")
test_result = lr_model.evaluate(test_df)

print("Test RMSE: %g" % test_result.rootMeanSquaredError)
print("Test R2: %g" % lr_evaluator.evaluate(lr_predictions))
# Out:
# Test RMSE: 10.6734
# Test R2: 0.0771897

# %% [markdown]
# The performance on the test set is not good as well. Let's try another regression method to compare the result.

# %% [markdown]
# ### 3.2 Decision Tree Regression

# %%
# Prepare the Features and Label
vectorAssembler = VectorAssembler(inputCols = ['Price', 'Required_Age', 'Is_multiplayer', 
                                               'Genre_vec', 'Publisher_vec', 'Developer_vec'], 
                                  outputCol = 'Features')
df_application_transformed_vec = vectorAssembler.transform(df_application_transformed)
df_application_transformed_vec = df_application_transformed_vec.select(['Features', 'Rating'])
df_application_transformed_vec.show(5)
# Out:
# +--------------------+------+
# |            Features|Rating|
# +--------------------+------+
# |(2141,[2,13,15,10...|    71|
# |(2141,[2,10,15,10...|    71|
# |(2141,[2,3,15,101...|    71|
# |(2141,[6,76,860],...|    67|
# |(2141,[4,76,860],...|    67|
# +--------------------+------+
# only showing top 5 rows

# %%
# Split into training set and testing set
splits = df_application_transformed_vec.randomSplit([0.7, 0.3])
train_df = splits[0]
test_df = splits[1]

# %%
dt = DecisionTreeRegressor(featuresCol ='Features', labelCol = 'Rating')
dt_model = dt.fit(train_df)

# %%
dt_predictions = dt_model.transform(test_df)
dt_predictions.show(10)
# Out:
# +--------------------+------+-----------------+
# |            Features|Rating|       prediction|
# +--------------------+------+-----------------+
# |(2141,[0,1,2,3,15...|    82|71.67455197132617|
# |(2141,[0,1,2,3,15...|    59|71.67455197132617|
# |(2141,[0,1,2,3,15...|    88|79.66981132075472|
# |(2141,[0,1,2,3,15...|    80|79.66981132075472|
# |(2141,[0,1,2,3,16...|    81|71.67455197132617|
# |(2141,[0,1,2,3,16...|    65|71.67455197132617|
# |(2141,[0,1,2,3,17...|    88|          87.4375|
# |(2141,[0,1,2,3,17...|    88|          87.4375|
# |(2141,[0,1,2,3,21...|    86|79.66981132075472|
# |(2141,[0,1,2,3,22...|    54|79.66981132075472|
# +--------------------+------+-----------------+
# only showing top 10 rows

# %%
dt_evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="Rating", metricName="rmse")
rmse = dt_evaluator.evaluate(dt_predictions)
print("Test RMSE = %g" % rmse)

dt_evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="Rating", metricName="r2")
print("Test R2: %g" % dt_evaluator.evaluate(dt_predictions))
# Out:
# Test RMSE = 10.6168
# Test R2: 0.0754085

# %% [markdown]
# Using Decision Tree Regression, the RMSE and R squared are almost the same as Linear Regression method.

# %% [markdown]
# ### 3.3 Conclusion and Future Works
#
# During my experiments, both regression method could not perform well. Some reasons behind it would be:
# - Lack of data
# - Incorrect feature representation
# - Unsuitable regression methods
#
# For future works, several things that might improve the results are:
# - Data augmentation
# - Feature engineering
